# %%
grades_last_2t = [1.25, 1.50, 1.00, 1.25]
grades_last_1t = [1.00, 1.25, 1.50, 1.75]

# %%
avg_2t = sum(grades_last_2t) / len(grades_last_2t)
avg_1t = sum(grades_last_1t) / len(grades_last_1t)

# %%
average_final_grades = [avg_2t, avg_1t]

# %%
print("=== COURSE FINAL GRADES ===")
print(f"Last 2T Grades: {grades_last_2t} | Average: {avg_2t:.2f}")
print(f"Last 1T Grades: {grades_last_1t} | Average: {avg_1t:.2f}")
print(f"List of Averages [2T, 1T]: {average_final_grades}\n")
# Out:
# === COURSE FINAL GRADES ===
# Last 2T Grades: [1.25, 1.5, 1.0, 1.25] | Average: 1.25
# Last 1T Grades: [1.0, 1.25, 1.5, 1.75] | Average: 1.38
# List of Averages [2T, 1T]: [1.25, 1.375]

# %%
senators = {
    "Risa Hontiveros": "Deputy Minority Leader",
    "Sherwin Gatchalian": "Chairperson, Committee on Basic Education",
    "Loren Legarda": "Senate President pro tempore",
    "Juan Miguel Zubiri": "Former Senate President",
    "Pia Cayetano": "Chairperson, Blue Ribbon Committee"
}

# %%
qc_previous_mayors = {
    "Herbert Bautista": "2010 - 2019",
    "Feliciano Belmonte Jr.": "2001 - 2010",
    "Ismael Mathay Jr.": "1992 - 2001",
    "Brigido Simon Jr.": "1986 - 1992",
    "Adelina Rodriguez": "1976 - 1986",
    "Norberto Amoranto": "1954 - 1976"
}

# %%
pokemon_pokedex = {
    1: "Bulbasaur (Grass/Poison)",
    2: "Ivysaur (Grass/Poison)",
    3: "Venusaur (Grass/Poison)",
    4: "Charmander (Fire)",
    5: "Charmeleon (Fire)",
    6: "Charizard (Fire/Flying)",
    7: "Squirtle (Water)",
    8: "Wartortle (Water)",
    9: "Blastoise (Water)",
    25: "Pikachu (Electric)",
    94: "Gengar (Ghost/Poison)",
    143: "Snorlax (Normal)",
    150: "Mewtwo (Psychic)"
}

# %%
print("=== PHILIPPINE SENATORS ===")
for name, role in senators.items():
    print(f"• {name}: {role}")
# Out:
# === PHILIPPINE SENATORS ===
# • Risa Hontiveros: Deputy Minority Leader
# • Sherwin Gatchalian: Chairperson, Committee on Basic Education
# • Loren Legarda: Senate President pro tempore
# • Juan Miguel Zubiri: Former Senate President
# • Pia Cayetano: Chairperson, Blue Ribbon Committee

# %%
print("\n=== PREVIOUS MAYORS OF QUEZON CITY ===")
for mayor, term in qc_previous_mayors.items():
    print(f"• Hon. {mayor} ({term})")
# Out:
# === PREVIOUS MAYORS OF QUEZON CITY ===
# • Hon. Herbert Bautista (2010 - 2019)
# • Hon. Feliciano Belmonte Jr. (2001 - 2010)
# • Hon. Ismael Mathay Jr. (1992 - 2001)
# • Hon. Brigido Simon Jr. (1986 - 1992)
# • Hon. Adelina Rodriguez (1976 - 1986)
# • Hon. Norberto Amoranto (1954 - 1976)

# %%
print("\n=== POKÉDEX (10+ POKÉMON) ===")
for dex_num, info in pokemon_pokedex.items():
    print(f"#{dex_num:03d} - {info}")
# Out:
# === POKÉDEX (10+ POKÉMON) ===
# #001 - Bulbasaur (Grass/Poison)
# #002 - Ivysaur (Grass/Poison)
# #003 - Venusaur (Grass/Poison)
# #004 - Charmander (Fire)
# #005 - Charmeleon (Fire)
# #006 - Charizard (Fire/Flying)
# #007 - Squirtle (Water)
# #008 - Wartortle (Water)
# #009 - Blastoise (Water)
# #025 - Pikachu (Electric)
# #094 - Gengar (Ghost/Poison)
# #143 - Snorlax (Normal)
# #150 - Mewtwo (Psychic)
