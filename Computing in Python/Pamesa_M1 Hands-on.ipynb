# %% [markdown]
# # This is a header (level 1)
# ## This is a header (level 2)
#
# For **Bold** text
#
# For *italicized* text
#
# For 'bulleted list':
# 1. item 1
# 2. item 2

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello Universe!")
# Out:
# Hello Universe!

# %%
print("Hello Philippines")
print("and")
print("hello world!")
# Out:
# Hello Philippines
# and
# hello world!

# %%
print(1+2)
# Out:
# 3

# %%
print(16*24)
# Out:
# 384

# %%
print("16 x 24 =", 16*24)
# Out:
# 16 x 24 = 384

# %%
3+4*5
# Out:
# 23

# %%
(3*4)/(2**2 + 4/2)
# Out:
# 2.0

# %%
import math
