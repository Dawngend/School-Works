# %%
a_string[4:9:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 a_string[4:9:2]
#
# NameError: name 'a_string' is not defined

# %%
a = "Hey There!"

# %%
a[0]
# Out:
# 'H'

# %%
a_string[4:9:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 a_string[4:9:2]
#
# NameError: name 'a_string' is not defined

# %%
a_string = "Hey There!"
a_string[4:9:2]
# Out:
# 'Tee'

# %%
a_string[4:]
# Out:
# 'There!'

# %%
a_string[:4]
# Out:
# 'Hey '

# %%
a_string[ :: 2]
# Out:
# 'HyTee'

# %%
a_string[4 :- 1]
# Out:
# 'There'

# %%
a_string[ ::- 1]
# Out:
# '!erehT yeH'

# %%
a_string = "Budget:"
another_string = "4000"
print(a_string + " " + another_string)
# Out:
# Budget: 4000

# %%
print("Budget: " + str(4000))
# Out:
# Budget: 4000

# %%
msg = "FEU Institute of Technology"

# %%
msg.upper()
# Out:
# 'FEU INSTITUTE OF TECHNOLOGY'

# %%
msg.count("e")
# Out:
# 2

# %%
msg.replace(" institute of technology", "TECH")
# Out:
# 'FEU Institute of Technology'

# %%
msg.replace(" institute of technology", "TECH")
# Out:
# 'FEU Institute of Technology'

# %%
msg
# Out:
# 'FEU Institute of Technology'

# %%
states = ["solid", "liquid", "gas"]
mixed_type_list = [1, "way", 2, "say", 3, "words"]

# %%
states[1]
# Out:
# 'liquid'

# %%
states[-1]
# Out:
# 'gas'

# %%
exam_scores = [90,83,85,77]
exam_scores.append(91)
exam_scores
# Out:
# [90, 83, 85, 77, 91]

# %%
pokemon = ["Pikachu", "Oshawott", "Goodra"]
pokemon.insert(1,"Oshawott")
pokemon
# Out:
# ['Pikachu', 'Oshawott', 'Oshawott', 'Goodra']

# %%
pokemon.remove("Oshawott")
pokemon
# Out:
# ['Pikachu', 'Oshawott', 'Goodra']

# %%
a_tuple=(1,1000,2,1000,3,1000)

# %%
len(a_tuple)
# Out:
# 6

# %%
a_tuple[2:]
# Out:
# (2, 1000, 3, 1000)

# %%
a_tuple.count(1000)
# Out:
# 3

# %%
a_list = [1,5,1,6,1,7]
a_list[0] = 2
a_list
# Out:
# [2, 5, 1, 6, 1, 7]

# %%
a_tuple[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 a_tuple[0]=2
#
# TypeError: 'tuple' object does not support item assignment

# %%
["paper", "pencil", "highlighter", "erase"]
# Out:
# ['paper', 'pencil', 'highlighter', 'erase']

# %%
[("paper",10), ("pencil",20), ("highlighter",5), ("erase",8)]
# Out:
# [('paper', 10), ('pencil', 20), ('highlighter', 5), ('erase', 8)]

# %%
delicacies = {}
delicacies["puto"] = "Calasiao"
delicacies["bibingka"] = "Vigan"
delicacies["ensaymada"] = "Bulacan"
delicacies["chili ice cream"] = "Bicol"
delicacies
# Out:
# {'puto': 'Calasiao',
#  'bibingka': 'Vigan',
#  'ensaymada': 'Bulacan',
#  'chili ice cream': 'Bicol'}

# %% [markdown]
# Dictionary: store dictionary keys in a list

# %%
{'puto': 'Calasiao', 'bibingka': 'Vigan', 'ensaymada': 'Bulacan'}
# Out:
# {'puto': 'Calasiao', 'bibingka': 'Vigan', 'ensaymada': 'Bulacan'}

# %%
delicacies
# Out:
# {'puto': 'Calasiao',
#  'bibingka': 'Vigan',
#  'ensaymada': 'Bulacan',
#  'chili ice cream': 'Bicol'}

# %%
delicacies["pichi-pichi"] = "Quezon"

# %%
delicacies
# Out:
# {'puto': 'Calasiao',
#  'bibingka': 'Vigan',
#  'ensaymada': 'Bulacan',
#  'chili ice cream': 'Bicol',
#  'pichi-pichi': 'Quezon'}
